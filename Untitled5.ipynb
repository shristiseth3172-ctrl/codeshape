# %%
# 1. Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import (
    classification_report, accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, roc_curve, auc
)
# 2. Load dataset
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
print("Dataset shape:", df.shape)
df.head()
# 3. Data Cleaning
# Convert TotalCharges to numeric (some empty strings exist)
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
df.dropna(subset=["TotalCharges"], inplace=True)

# Convert target 'Churn' to numeric
df['Churn'] = df['Churn'].map({'No': 0, 'Yes': 1})

# Drop customerID (not useful)
df.drop('customerID', axis=1, inplace=True)

# 4. Feature Engineering
# Scale numeric columns
scaler = StandardScaler()
df[['MonthlyCharges','tenure','TotalCharges']] = scaler.fit_transform(
    df[['MonthlyCharges','tenure','TotalCharges']]
)

# One-hot encode categorical features
df_encoded = pd.get_dummies(df, drop_first=True)

# Separate features and target
X = df_encoded.drop("Churn", axis=1)
y = df_encoded["Churn"]

print("Features shape:", X.shape)
print("Target distribution:\n", y.value_counts())
# 5. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# 6. Define models
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(n_estimators=200, random_state=42),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
}

#7.EDA:
#1. Churn Distribution:
plt.figure(figsize=(6,4))
sns.countplot(x='Churn', data=df)
plt.title("Churn Distribution")
plt.show()
#2. Churn by Contract Type: 
plt.figure(figsize=(6,4))
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title("Churn by Contract Type")
plt.show()
#3. Churn by Payment Method
plt.figure(figsize=(8,4))
sns.countplot(x='PaymentMethod', hue='Churn', data=df)
plt.title("Churn by Payment Method")
plt.xticks(rotation=45)
plt.show()
#4. Churn vs Tenure
plt.figure(figsize=(6,4))
sns.kdeplot(data=df, x='tenure', hue='Churn', fill=True)
plt.title("Churn vs Tenure Distribution")
plt.show()
#5. Monthly Charges vs Churn
plt.figure(figsize=(6,4))
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title("Monthly Charges vs Churn")
plt.show()


# 8. Train & evaluate
results = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:,1]

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc_score = roc_auc_score(y_test, y_prob)

    results[name] = [acc, prec, rec, f1, auc_score]

    print(f"\n{name} Results:")
    print("Accuracy :", acc)
    print("Precision:", prec)
    print("Recall   :", rec)
    print("F1-Score :", f1)
    print("ROC-AUC  :", auc_score)
    print(classification_report(y_test, y_pred))

# 9. Results summary
results_df = pd.DataFrame(results, index=["Accuracy","Precision","Recall","F1-Score","ROC-AUC"])
print("\nModel Comparison:\n")
print(results_df)

# 10. ROC Curve Comparison
plt.figure(figsize=(8,6))

for name, model in models.items():
    y_prob = model.predict_proba(X_test)[:,1]
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    plt.plot(fpr, tpr, label=f"{name} (AUC={auc(fpr,tpr):.2f})")

plt.plot([0,1],[0,1],'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.show()
# Out:
# Dataset shape: (7043, 21)
# Features shape: (7032, 30)
# Target distribution:
#  Churn
# 0    5163
# 1    1869
# Name: count, dtype: int64
# Logistic Regression Results:
# Accuracy : 0.8056872037914692
# Precision: 0.6556701030927835
# Recall   : 0.5668449197860963
# F1-Score : 0.6080305927342257
# ROC-AUC  : 0.8378949560926547
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1549
#            1       0.66      0.57      0.61       561
#
#     accuracy                           0.81      2110
#    macro avg       0.75      0.73      0.74      2110
# weighted avg       0.80      0.81      0.80      2110
#
#
# Random Forest Results:
# Accuracy : 0.7815165876777251
# Precision: 0.616822429906542
# Recall   : 0.47058823529411764
# F1-Score : 0.5338725985844287
# ROC-AUC  : 0.8163170074649966
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1549
#            1       0.62      0.47      0.53       561
#
#     accuracy                           0.78      2110
#    macro avg       0.72      0.68      0.70      2110
# weighted avg       0.77      0.78      0.77      2110
# C:\Users\priya\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [20:39:43] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost Results:
# Accuracy : 0.7791469194312797
# Precision: 0.5967413441955194
# Recall   : 0.5222816399286988
# F1-Score : 0.5570342205323194
# ROC-AUC  : 0.8140298668912955
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85      1549
#            1       0.60      0.52      0.56       561
#
#     accuracy                           0.78      2110
#    macro avg       0.72      0.70      0.70      2110
# weighted avg       0.77      0.78      0.77      2110
#
#
# Model Comparison:
#
#            Logistic Regression  Random Forest   XGBoost
# Accuracy              0.805687       0.781517  0.779147
# Precision             0.655670       0.616822  0.596741
# Recall                0.566845       0.470588  0.522282
# F1-Score              0.608031       0.533873  0.557034
# ROC-AUC               0.837895       0.816317  0.814030
